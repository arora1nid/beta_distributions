# %%
import pandas as pd
import numpy as np
from scipy import stats
from collections import Counter
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# Activity for CLT for after lecture.
# The CLT is good for all distributions.
#
# Work in groups. Look up the 'beta distribution' on wikipedia and the internets. (Note: it is not the same as the beta function!)
#
# Functions using the beta distribution can be found in python in the scipy module via stats.beta
#
# Part 1: Explore the Beta Distribution
# The beta distribution has two parameter, a and b.
# set a=1, b=1 and use stats.beta.rvs to generate size=20, size=50, size=1000, and size=100,000 random variables from the resulting beta distribution. Graph using seaborn's distplot function. What do you think the min, max, mean, and median of the beta distribution are (with a=1, b=1) as size gets infinitely large? Discuss your findings within your group.
#
# repeat the same for a =20, b = 20
# repeat the same for a = 5, b = 20
# repeat the same for a = 20, b = 5
#
# Part 2: Apply the CLT to the Beta Distribution
# Using a=20 and b=20, generate 50, 100, 200, and 500 samples of length 30 each, find the means of each of the samples, and plot the sample means separately, using distplot. Do the plots of the distributions of the sample means look normal?
# repeat for a=2, b=20
#
# Do you think samples of length 30 are big enough to guarantee that the sample means drawn from these distributions are approximately normal in the two cases above? Why or why not?

# %%
b = stats.beta.rvs(a = 1, b = 1, size = 20)
sns.distplot(b) 
print(f"\n min={np.min(b)}\n max={np.max(b)}\n median={np.median(b)}\n mean={np.mean(b)}\n std={np.std(b, ddof=1)}\n" )
c = stats.beta.rvs(a = 20, b = 20, size = (500000, 50))
sns.distplot(np.mean(c, axis = 0))
# Out:
#  min=0.13136628813183795
#  max=0.9781122882670136
#  median=0.6650970781336838
#  mean=0.6448077207683629
#  std=0.26993478974993335

# %%
c = stats.beta.rvs(a = 1, b = 1, size = (20, 25))
sns.distplot(np.mean(c, axis = 0))

# %% [markdown]
# Part 1: Explore the Beta Distribution The beta distribution has two parameter, a and b. set a=1, b=1 and use stats.beta.rvs to generate size=20, size=50, size=1000, and size=100,000 random variables from the resulting beta distribution. Graph using seaborn's distplot function. What do you think the min, max, mean, and median of the beta distribution are (with a=1, b=1) as size gets infinitely large? Discuss your findings within your group.
#
# repeat the same for a =20, b = 20 repeat the same for a = 5, b = 20 repeat the same for a = 20, b = 5

# %%
a = 1
b = 1
twenty = stats.beta.rvs(a, b, size = 20)
sns.distplot(twenty)

# %%
a = 1
b = 1
twenty = stats.beta.rvs(a, b, size = 50)
sns.distplot(twenty)
